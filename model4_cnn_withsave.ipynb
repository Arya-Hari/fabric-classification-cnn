# %% [markdown]
# <a href="https://colab.research.google.com/github/Arya-Hari/fabric-classification-cnn/blob/main/model4_cnn_withsave.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp drive/MyDrive/my_utils.py .
import my_utils

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import re
import pathlib
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint

path = "/content/drive/MyDrive/Fabrics_adjusted"

data_dir = pathlib.Path(path)

# %%
batch_size = 32
img_height = 400
img_width = 400

train_ds, val_ds, class_names = my_utils.generate_ds(data_dir, batch_size, img_height, img_width)

print(class_names)
# Out:
# Found 4708 files belonging to 6 classes.
# Using 3767 files for training.
# Found 4708 files belonging to 6 classes.
# Using 941 files for validation.
# ['Cotton', 'Denim', 'Nylon', 'Polyester', 'Silk', 'Wool']

# %%
#data augmentation based of https://keras.io/examples/vision/image_classification_from_scratch/

#the augmentations to make
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomRotation(0.5)
    ]
)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#based of https://www.tensorflow.org/tutorials/load_data/images
num_classes = 6

norm = 0.0
dropout_val = 0.6

model = tf.keras.Sequential([
  data_augmentation,
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, input_shape=(32, 400, 400, 3), activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(64, 3, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),
  tf.keras.layers.Dropout(dropout_val),
  tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l1(norm)),

  tf.keras.layers.Dense(num_classes)
])

model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

checkpoint = my_utils.generate_callback("/content/drive/MyDrive/", "Model-4a-Aug-fa")

hist = model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 50,
    verbose = 1,
    callbacks = [checkpoint])

model.summary()
# Out:
# Epoch 1/50
# 118/118 [==============================] - ETA: 0s - loss: 1.4817 - accuracy: 0.4900
# Epoch 1: val_accuracy improved from -inf to 0.47609, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 118/118 [==============================] - 346s 3s/step - loss: 1.4817 - accuracy: 0.4900 - val_loss: 1.3949 - val_accuracy: 0.4761
# Epoch 2/50
# 118/118 [==============================] - ETA: 0s - loss: 1.3827 - accuracy: 0.5277
# Epoch 2: val_accuracy improved from 0.47609 to 0.52816, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 18s 149ms/step - loss: 1.3827 - accuracy: 0.5277 - val_loss: 1.3114 - val_accuracy: 0.5282
# Epoch 3/50
# 118/118 [==============================] - ETA: 0s - loss: 1.2926 - accuracy: 0.5556
# Epoch 3: val_accuracy improved from 0.52816 to 0.53241, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 20s 168ms/step - loss: 1.2926 - accuracy: 0.5556 - val_loss: 1.2674 - val_accuracy: 0.5324
# Epoch 4/50
# 118/118 [==============================] - ETA: 0s - loss: 1.2470 - accuracy: 0.5609
# Epoch 4: val_accuracy improved from 0.53241 to 0.54516, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 19s 158ms/step - loss: 1.2470 - accuracy: 0.5609 - val_loss: 1.3405 - val_accuracy: 0.5452
# Epoch 5/50
# 118/118 [==============================] - ETA: 0s - loss: 1.1694 - accuracy: 0.6021
# Epoch 5: val_accuracy improved from 0.54516 to 0.56323, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 19s 164ms/step - loss: 1.1694 - accuracy: 0.6021 - val_loss: 1.2607 - val_accuracy: 0.5632
# Epoch 6/50
# 118/118 [==============================] - ETA: 0s - loss: 1.1502 - accuracy: 0.6193
# Epoch 6: val_accuracy improved from 0.56323 to 0.59299, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 24s 202ms/step - loss: 1.1502 - accuracy: 0.6193 - val_loss: 1.2092 - val_accuracy: 0.5930
# Epoch 7/50
# 118/118 [==============================] - ETA: 0s - loss: 1.0716 - accuracy: 0.6368
# Epoch 7: val_accuracy improved from 0.59299 to 0.61424, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 17s 143ms/step - loss: 1.0716 - accuracy: 0.6368 - val_loss: 1.1101 - val_accuracy: 0.6142
# Epoch 8/50
# 118/118 [==============================] - ETA: 0s - loss: 1.0624 - accuracy: 0.6437
# Epoch 8: val_accuracy improved from 0.61424 to 0.66100, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 20s 167ms/step - loss: 1.0624 - accuracy: 0.6437 - val_loss: 1.0146 - val_accuracy: 0.6610
# Epoch 9/50
# 118/118 [==============================] - ETA: 0s - loss: 1.0275 - accuracy: 0.6501
# Epoch 9: val_accuracy did not improve from 0.66100
# 118/118 [==============================] - 14s 115ms/step - loss: 1.0275 - accuracy: 0.6501 - val_loss: 1.1807 - val_accuracy: 0.5951
# Epoch 10/50
# 118/118 [==============================] - ETA: 0s - loss: 1.0226 - accuracy: 0.6554
# Epoch 10: val_accuracy did not improve from 0.66100
# 118/118 [==============================] - 14s 115ms/step - loss: 1.0226 - accuracy: 0.6554 - val_loss: 1.0401 - val_accuracy: 0.6355
# Epoch 11/50
# 118/118 [==============================] - ETA: 0s - loss: 0.9965 - accuracy: 0.6626
# Epoch 11: val_accuracy did not improve from 0.66100
# 118/118 [==============================] - 14s 115ms/step - loss: 0.9965 - accuracy: 0.6626 - val_loss: 1.0655 - val_accuracy: 0.6291
# Epoch 12/50
# 118/118 [==============================] - ETA: 0s - loss: 0.9814 - accuracy: 0.6637
# Epoch 12: val_accuracy improved from 0.66100 to 0.66738, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 20s 167ms/step - loss: 0.9814 - accuracy: 0.6637 - val_loss: 0.9443 - val_accuracy: 0.6674
# Epoch 13/50
# 118/118 [==============================] - ETA: 0s - loss: 0.9732 - accuracy: 0.6626
# Epoch 13: val_accuracy improved from 0.66738 to 0.66844, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 23s 191ms/step - loss: 0.9732 - accuracy: 0.6626 - val_loss: 0.9575 - val_accuracy: 0.6684
# Epoch 14/50
# 118/118 [==============================] - ETA: 0s - loss: 0.9489 - accuracy: 0.6740
# Epoch 14: val_accuracy did not improve from 0.66844
# 118/118 [==============================] - 14s 114ms/step - loss: 0.9489 - accuracy: 0.6740 - val_loss: 1.0180 - val_accuracy: 0.6238
# Epoch 15/50
# 118/118 [==============================] - ETA: 0s - loss: 0.9310 - accuracy: 0.6700
# Epoch 15: val_accuracy did not improve from 0.66844
# 118/118 [==============================] - 14s 116ms/step - loss: 0.9310 - accuracy: 0.6700 - val_loss: 1.1671 - val_accuracy: 0.5728
# Epoch 16/50
# 118/118 [==============================] - ETA: 0s - loss: 0.9246 - accuracy: 0.6796
# Epoch 16: val_accuracy did not improve from 0.66844
# 118/118 [==============================] - 14s 116ms/step - loss: 0.9246 - accuracy: 0.6796 - val_loss: 0.9727 - val_accuracy: 0.6546
# Epoch 17/50
# 118/118 [==============================] - ETA: 0s - loss: 0.9058 - accuracy: 0.6833
# Epoch 17: val_accuracy improved from 0.66844 to 0.67906, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 15s 130ms/step - loss: 0.9058 - accuracy: 0.6833 - val_loss: 0.9252 - val_accuracy: 0.6791
# Epoch 18/50
# 118/118 [==============================] - ETA: 0s - loss: 0.8749 - accuracy: 0.6883
# Epoch 18: val_accuracy improved from 0.67906 to 0.69819, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 21s 179ms/step - loss: 0.8749 - accuracy: 0.6883 - val_loss: 0.8109 - val_accuracy: 0.6982
# Epoch 19/50
# 118/118 [==============================] - ETA: 0s - loss: 0.8485 - accuracy: 0.6992
# Epoch 19: val_accuracy did not improve from 0.69819
# 118/118 [==============================] - 14s 115ms/step - loss: 0.8485 - accuracy: 0.6992 - val_loss: 0.8556 - val_accuracy: 0.6897
# Epoch 20/50
# 118/118 [==============================] - ETA: 0s - loss: 0.8485 - accuracy: 0.6984
# Epoch 20: val_accuracy improved from 0.69819 to 0.71626, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 19s 165ms/step - loss: 0.8485 - accuracy: 0.6984 - val_loss: 0.7991 - val_accuracy: 0.7163
# Epoch 21/50
# 118/118 [==============================] - ETA: 0s - loss: 0.8311 - accuracy: 0.7064
# Epoch 21: val_accuracy did not improve from 0.71626
# 118/118 [==============================] - 14s 115ms/step - loss: 0.8311 - accuracy: 0.7064 - val_loss: 0.8286 - val_accuracy: 0.7003
# Epoch 22/50
# 118/118 [==============================] - ETA: 0s - loss: 0.8184 - accuracy: 0.7141
# Epoch 22: val_accuracy improved from 0.71626 to 0.71838, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 19s 158ms/step - loss: 0.8184 - accuracy: 0.7141 - val_loss: 0.7614 - val_accuracy: 0.7184
# Epoch 23/50
# 118/118 [==============================] - ETA: 0s - loss: 0.7958 - accuracy: 0.7154
# Epoch 23: val_accuracy improved from 0.71838 to 0.73220, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 22s 184ms/step - loss: 0.7958 - accuracy: 0.7154 - val_loss: 0.7547 - val_accuracy: 0.7322
# Epoch 24/50
# 118/118 [==============================] - ETA: 0s - loss: 0.7903 - accuracy: 0.7157
# Epoch 24: val_accuracy did not improve from 0.73220
# 118/118 [==============================] - 14s 115ms/step - loss: 0.7903 - accuracy: 0.7157 - val_loss: 0.7596 - val_accuracy: 0.7216
# Epoch 25/50
# 118/118 [==============================] - ETA: 0s - loss: 0.7645 - accuracy: 0.7250
# Epoch 25: val_accuracy did not improve from 0.73220
# 118/118 [==============================] - 14s 115ms/step - loss: 0.7645 - accuracy: 0.7250 - val_loss: 0.7689 - val_accuracy: 0.7301
# Epoch 26/50
# 118/118 [==============================] - ETA: 0s - loss: 0.7477 - accuracy: 0.7260
# Epoch 26: val_accuracy did not improve from 0.73220
# 118/118 [==============================] - 14s 115ms/step - loss: 0.7477 - accuracy: 0.7260 - val_loss: 0.7613 - val_accuracy: 0.7205
# Epoch 27/50
# 118/118 [==============================] - ETA: 0s - loss: 0.7383 - accuracy: 0.7348
# Epoch 27: val_accuracy did not improve from 0.73220
# 118/118 [==============================] - 14s 115ms/step - loss: 0.7383 - accuracy: 0.7348 - val_loss: 0.7240 - val_accuracy: 0.7322
# Epoch 28/50
# 118/118 [==============================] - ETA: 0s - loss: 0.7510 - accuracy: 0.7319
# Epoch 28: val_accuracy improved from 0.73220 to 0.74176, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 19s 158ms/step - loss: 0.7510 - accuracy: 0.7319 - val_loss: 0.7064 - val_accuracy: 0.7418
# Epoch 29/50
# 118/118 [==============================] - ETA: 0s - loss: 0.7200 - accuracy: 0.7409
# Epoch 29: val_accuracy did not improve from 0.74176
# 118/118 [==============================] - 14s 115ms/step - loss: 0.7200 - accuracy: 0.7409 - val_loss: 0.6792 - val_accuracy: 0.7418
# Epoch 30/50
# 118/118 [==============================] - ETA: 0s - loss: 0.7060 - accuracy: 0.7369
# Epoch 30: val_accuracy did not improve from 0.74176
# 118/118 [==============================] - 14s 116ms/step - loss: 0.7060 - accuracy: 0.7369 - val_loss: 0.9039 - val_accuracy: 0.6812
# Epoch 31/50
# 118/118 [==============================] - ETA: 0s - loss: 0.7163 - accuracy: 0.7446
# Epoch 31: val_accuracy did not improve from 0.74176
# 118/118 [==============================] - 14s 116ms/step - loss: 0.7163 - accuracy: 0.7446 - val_loss: 0.7750 - val_accuracy: 0.7396
# Epoch 32/50
# 118/118 [==============================] - ETA: 0s - loss: 0.6683 - accuracy: 0.7544
# Epoch 32: val_accuracy improved from 0.74176 to 0.77790, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 24s 202ms/step - loss: 0.6683 - accuracy: 0.7544 - val_loss: 0.6357 - val_accuracy: 0.7779
# Epoch 33/50
# 118/118 [==============================] - ETA: 0s - loss: 0.6711 - accuracy: 0.7515
# Epoch 33: val_accuracy did not improve from 0.77790
# 118/118 [==============================] - 14s 115ms/step - loss: 0.6711 - accuracy: 0.7515 - val_loss: 0.7075 - val_accuracy: 0.7503
# Epoch 34/50
# 118/118 [==============================] - ETA: 0s - loss: 0.6594 - accuracy: 0.7505
# Epoch 34: val_accuracy did not improve from 0.77790
# 118/118 [==============================] - 14s 115ms/step - loss: 0.6594 - accuracy: 0.7505 - val_loss: 0.6507 - val_accuracy: 0.7705
# Epoch 35/50
# 118/118 [==============================] - ETA: 0s - loss: 0.6367 - accuracy: 0.7619
# Epoch 35: val_accuracy did not improve from 0.77790
# 118/118 [==============================] - 14s 116ms/step - loss: 0.6367 - accuracy: 0.7619 - val_loss: 0.6559 - val_accuracy: 0.7630
# Epoch 36/50
# 118/118 [==============================] - ETA: 0s - loss: 0.6377 - accuracy: 0.7608
# Epoch 36: val_accuracy did not improve from 0.77790
# 118/118 [==============================] - 14s 115ms/step - loss: 0.6377 - accuracy: 0.7608 - val_loss: 0.7315 - val_accuracy: 0.7343
# Epoch 37/50
# 118/118 [==============================] - ETA: 0s - loss: 0.6382 - accuracy: 0.7537
# Epoch 37: val_accuracy did not improve from 0.77790
# 118/118 [==============================] - 14s 115ms/step - loss: 0.6382 - accuracy: 0.7537 - val_loss: 0.6747 - val_accuracy: 0.7641
# Epoch 38/50
# 118/118 [==============================] - ETA: 0s - loss: 0.6309 - accuracy: 0.7693
# Epoch 38: val_accuracy did not improve from 0.77790
# 118/118 [==============================] - 14s 115ms/step - loss: 0.6309 - accuracy: 0.7693 - val_loss: 0.6847 - val_accuracy: 0.7641
# Epoch 39/50
# 118/118 [==============================] - ETA: 0s - loss: 0.6124 - accuracy: 0.7640
# Epoch 39: val_accuracy did not improve from 0.77790
# 118/118 [==============================] - 14s 115ms/step - loss: 0.6124 - accuracy: 0.7640 - val_loss: 0.6782 - val_accuracy: 0.7556
# Epoch 40/50
# 118/118 [==============================] - ETA: 0s - loss: 0.6188 - accuracy: 0.7736
# Epoch 40: val_accuracy did not improve from 0.77790
# 118/118 [==============================] - 14s 115ms/step - loss: 0.6188 - accuracy: 0.7736 - val_loss: 0.8599 - val_accuracy: 0.7109
# Epoch 41/50
# 118/118 [==============================] - ETA: 0s - loss: 0.5925 - accuracy: 0.7736
# Epoch 41: val_accuracy did not improve from 0.77790
# 118/118 [==============================] - 14s 116ms/step - loss: 0.5925 - accuracy: 0.7736 - val_loss: 0.6279 - val_accuracy: 0.7673
# Epoch 42/50
# 118/118 [==============================] - ETA: 0s - loss: 0.5843 - accuracy: 0.7789
# Epoch 42: val_accuracy improved from 0.77790 to 0.78215, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 20s 168ms/step - loss: 0.5843 - accuracy: 0.7789 - val_loss: 0.6133 - val_accuracy: 0.7821
# Epoch 43/50
# 118/118 [==============================] - ETA: 0s - loss: 0.5735 - accuracy: 0.7858
# Epoch 43: val_accuracy did not improve from 0.78215
# 118/118 [==============================] - 14s 116ms/step - loss: 0.5735 - accuracy: 0.7858 - val_loss: 0.5775 - val_accuracy: 0.7811
# Epoch 44/50
# 118/118 [==============================] - ETA: 0s - loss: 0.5817 - accuracy: 0.7860
# Epoch 44: val_accuracy did not improve from 0.78215
# 118/118 [==============================] - 14s 115ms/step - loss: 0.5817 - accuracy: 0.7860 - val_loss: 0.5995 - val_accuracy: 0.7736
# Epoch 45/50
# 118/118 [==============================] - ETA: 0s - loss: 0.5785 - accuracy: 0.7860
# Epoch 45: val_accuracy did not improve from 0.78215
# 118/118 [==============================] - 14s 116ms/step - loss: 0.5785 - accuracy: 0.7860 - val_loss: 0.7311 - val_accuracy: 0.7524
# Epoch 46/50
# 118/118 [==============================] - ETA: 0s - loss: 0.5785 - accuracy: 0.7802
# Epoch 46: val_accuracy improved from 0.78215 to 0.80659, saving model to /content/drive/MyDrive/Model-4a-Aug-fa.h5
# 118/118 [==============================] - 19s 162ms/step - loss: 0.5785 - accuracy: 0.7802 - val_loss: 0.5308 - val_accuracy: 0.8066
# Epoch 47/50
# 118/118 [==============================] - ETA: 0s - loss: 0.5578 - accuracy: 0.7951
# Epoch 47: val_accuracy did not improve from 0.80659
# 118/118 [==============================] - 14s 116ms/step - loss: 0.5578 - accuracy: 0.7951 - val_loss: 0.6246 - val_accuracy: 0.7758
# Epoch 48/50
# 118/118 [==============================] - ETA: 0s - loss: 0.5689 - accuracy: 0.7900
# Epoch 48: val_accuracy did not improve from 0.80659
# 118/118 [==============================] - 14s 115ms/step - loss: 0.5689 - accuracy: 0.7900 - val_loss: 0.6016 - val_accuracy: 0.7790
# Epoch 49/50
# 118/118 [==============================] - ETA: 0s - loss: 0.5850 - accuracy: 0.7884
# Epoch 49: val_accuracy did not improve from 0.80659
# 118/118 [==============================] - 14s 116ms/step - loss: 0.5850 - accuracy: 0.7884 - val_loss: 0.6129 - val_accuracy: 0.7705
# Epoch 50/50
# 118/118 [==============================] - ETA: 0s - loss: 0.5467 - accuracy: 0.7935
# Epoch 50: val_accuracy did not improve from 0.80659
# 118/118 [==============================] - 14s 117ms/step - loss: 0.5467 - accuracy: 0.7935 - val_loss: 0.6322 - val_accuracy: 0.7736
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 400, 400, 3)       0
#
#  rescaling (Rescaling)       (None, 400, 400, 3)       0
#
#  conv2d (Conv2D)             (None, 398, 398, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 199, 199, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 197, 197, 32)      9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 98, 98, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 96, 96, 32)        9248
#
#  max_pooling2d_2 (MaxPoolin  (None, 48, 48, 32)        0
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 46, 46, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 23, 23, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 33856)             0
#
#  dense (Dense)               (None, 128)               4333696
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 4380230 (16.71 MB)
# Trainable params: 4380230 (16.71 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
my_utils.generate_plot(hist)
# Out:
# 0

# %%
img_path = "/content/drive/MyDrive/dn2.jpg"

img = tf.keras.utils.load_img(
    img_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 467ms/step
# This image most likely belongs to Cotton with a 88.56 percent confidence.

# %%
img_path = "/content/drive/MyDrive/images.jpeg"

img = tf.keras.utils.load_img(
    img_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# This image most likely belongs to Cotton with a 87.93 percent confidence.

# %%
# !pip install h5py
import h5py
import keras
from keras.models import Sequential
from keras.layers import Dense

# Get the model from the global variables
model = globals()["model"]

# Save the model
model.save('model.h5')
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.25.2)
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
